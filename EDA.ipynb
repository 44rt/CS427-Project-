# %% [markdown]
# # Exploratory Data Analysis
# Exploring raw BTS1 file

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Loading the dataset
df1 = pd.read_csv('/Users/roskat/Desktop/CS427/data/BTS_1.csv')
df2 = pd.read_csv('/Users/roskat/Desktop/CS427/data/BTS_2.csv')
# Out:
# /var/folders/v3/9vhsqmm10zd5wzyzbk2jb9wr0000gn/T/ipykernel_63665/1901380473.py:7: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('/Users/roskat/Desktop/CS427/data/BTS_1.csv')
# /var/folders/v3/9vhsqmm10zd5wzyzbk2jb9wr0000gn/T/ipykernel_63665/1901380473.py:8: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('/Users/roskat/Desktop/CS427/data/BTS_2.csv')

# %% [markdown]
# ## Quick look at the data
# Looking at the data types of the data as well as look into the descriptive statistics of a DataFrame

# %% [markdown]
# ### BTS1 Overlook

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 728316 entries, 0 to 728315
# Data columns (total 52 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Flgs         728316 non-null  object
#  1   Seq          728316 non-null  int64
#  2   Dur          728316 non-null  float64
#  3   RunTime      728316 non-null  float64
#  4   Mean         728316 non-null  float64
#  5   Sum          728316 non-null  float64
#  6   Min          728316 non-null  float64
#  7   Max          728316 non-null  float64
#  8   Proto        728316 non-null  object
#  9   sTos         728116 non-null  float64
#  10  dTos         146863 non-null  float64
#  11  sDSb         728116 non-null  object
#  12  dDSb         146863 non-null  object
#  13  sTtl         728116 non-null  float64
#  14  dTtl         146863 non-null  float64
#  15  sHops        728116 non-null  float64
#  16  dHops        146863 non-null  float64
# ...

# %%
df1.describe()
# Out:
#                  Seq            Dur        RunTime           Mean  \
# count  728316.000000  728316.000000  728316.000000  728316.000000
# mean    51282.395176       1.426883       1.426883       1.426883
# std     42867.611959       1.750249       1.750249       1.750249
# min         1.000000       0.000000       0.000000       0.000000
# 25%     10953.000000       0.000000       0.000000       0.000000
# 50%     36820.000000       0.000000       0.000000       0.000000
# 75%     90470.000000       2.581113       2.581113       2.581113
# max    137210.000000      19.920630      19.920630      19.920630
#
#                  Sum            Min            Max           sTos  \
# count  728316.000000  728316.000000  728316.000000  728116.000000
# mean        1.426883       1.426883       1.426883       0.753969
# std         1.750249       1.750249       1.750249      11.620346
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# Missing Values

# %%
# Missing values
df1.isna().sum().sort_values(ascending=False)
# Out:
# dVid           727563
# sVid           655330
# DstWin         637519
# DstTCPBase     608700
# SrcWin         603047
# SrcGap         582815
# DstGap         582815
# SrcTCPBase     582815
# dDSb           581453
# dTtl           581453
# dHops          581453
# dTos           581453
# sTtl              200
# sTos              200
# sDSb              200
# sHops             200
# RunTime             0
# Dur                 0
# Seq                 0
# Flgs                0
# SrcPkts             0
# TotPkts             0
# Cause               0
# Mean                0
# Max                 0
# Min                 0
# Sum                 0
# Proto               0
# Load                0
# dMeanPktSz          0
# DstPkts             0
# TotBytes            0
# Offset              0
# sMeanPktSz          0
# SrcBytes            0
# DstBytes            0
# DstLoss             0
# pLoss               0
# Loss                0
# SrcLoss             0
# DstLoad             0
# ...

# %%
# Benign vs Malicious
plt.figure(figsize=(6,4))
df1['Label'].value_counts().plot(kind="bar")
plt.title("Benign vs Malicious (BTS1)")
plt.show()

# %%
# Attack-type frequencies
if 'Attack Type' in df.columns:
    plt.figure(figsize=(10,4))
    df1['Attack Type'].value_counts().plot(kind="bar")
    plt.title("Attack Types (BTS1)")
    plt.show()

# %%
# Correlation heatmap for numeric columns
num_cols = df1.select_dtypes("number")
plt.figure(figsize=(12,8))
sns.heatmap(num_cols.corr(), cmap="coolwarm")
plt.title("Numeric Feature Correlations (BTS1)")
plt.show()

# %% [markdown]
# ### BTS2 Data Overlook

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 487574 entries, 0 to 487573
# Data columns (total 52 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Flgs         487574 non-null  object
#  1   Seq          487574 non-null  int64
#  2   Dur          487574 non-null  float64
#  3   RunTime      487574 non-null  float64
#  4   Mean         487574 non-null  float64
#  5   Sum          487574 non-null  float64
#  6   Min          487574 non-null  float64
#  7   Max          487574 non-null  float64
#  8   Proto        487574 non-null  object
#  9   sTos         487560 non-null  float64
#  10  dTos         125960 non-null  float64
#  11  sDSb         487560 non-null  object
#  12  dDSb         125960 non-null  object
#  13  sTtl         487560 non-null  float64
#  14  dTtl         125960 non-null  float64
#  15  sHops        487560 non-null  float64
#  16  dHops        125960 non-null  float64
# ...

# %%
df2.describe()
# Out:
#                  Seq            Dur        RunTime           Mean  \
# count  487574.000000  487574.000000  487574.000000  487574.000000
# mean    24003.066232       1.272165       1.272165       1.272165
# std     19161.948365       1.594701       1.594701       1.594701
# min         1.000000       0.000000       0.000000       0.000000
# 25%      6670.000000       0.000000       0.000000       0.000000
# 50%     20365.000000       0.000000       0.000000       0.000000
# 75%     38444.000000       2.579855       2.579855       2.579855
# max     68465.000000       5.978457       5.978457       5.978457
#
#                  Sum            Min            Max           sTos  \
# count  487574.000000  487574.000000  487574.000000  487560.000000
# mean        1.272165       1.272165       1.272165       1.029272
# std         1.594701       1.594701       1.594701      13.750395
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
# Missing Values
df2.isna().sum().sort_values(ascending=False)
# Out:
# dVid           486318
# sVid           445989
# DstWin         401293
# DstTCPBase     377143
# SrcWin         370423
# dDSb           361614
# dHops          361614
# dTtl           361614
# dTos           361614
# SrcGap         354404
# DstGap         354404
# SrcTCPBase     354404
# sTtl               14
# sTos               14
# sDSb               14
# sHops              14
# RunTime             0
# Dur                 0
# Seq                 0
# Flgs                0
# SrcPkts             0
# TotPkts             0
# Cause               0
# Mean                0
# Max                 0
# Min                 0
# Sum                 0
# Proto               0
# Load                0
# dMeanPktSz          0
# DstPkts             0
# TotBytes            0
# Offset              0
# sMeanPktSz          0
# SrcBytes            0
# DstBytes            0
# DstLoss             0
# pLoss               0
# Loss                0
# SrcLoss             0
# DstLoad             0
# ...

# %%
# Benign vs Malicious
plt.figure(figsize=(6,4))
df2['Label'].value_counts().plot(kind="bar")
plt.title("Benign vs Malicious (BTS2)")
plt.show()

# %%
# Attack-type frequencies
if 'Attack Type' in df2.columns:
    plt.figure(figsize=(10,4))
    df2['Attack Type'].value_counts().plot(kind="bar")
    plt.title("Attack Types (BTS2)")
    plt.show()

# %%
# Correlation heatmap for numeric columns
num_cols = df2.select_dtypes("number")
plt.figure(figsize=(12,8))
sns.heatmap(num_cols.corr(), cmap="coolwarm")
plt.title("Numeric Feature Correlations (BTS2)")
plt.show()
